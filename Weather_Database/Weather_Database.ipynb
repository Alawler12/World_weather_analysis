# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
# assigns arrays of random floats to variables
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# zip funtion combines the two new arrays into an object in memory
# each lat and lng with the same index in their own array, are paired into a tuple in the new zipped array
# in lat_lngs, the lat is index 0 and lng index 1 in each tuple.  each tuple is a full coordinate
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Assinging the zipped array to a list
# you can only unzip a zipped tuple once before it's removed from memory
coordinates = list(lat_lngs)

# %%
#import citipy
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 733

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters to track progress.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
# enumerate method is a shortcut for referencing by each city's index but returning the city name
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Adds city name to our base URL by creating an endpoint URL with each city. 
    # the .replace removes empty space and concatenates if the city name has a space 
    # otherwise it would find weather data for Cabo instead of Cabo San Lucas
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    # this will run through each city and make an api call based on the city_url created above
    #try except blocks lets the code continue even if an error occurs
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        
        
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city. 
    except:
        print("City not found. Skipping...")
        #general purpose statement to handle all errors eincounter and continue the program
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | anchorage
# Processing Record 2 of Set 1 | carnarvon
# Processing Record 3 of Set 1 | maragogi
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | bathsheba
# Processing Record 6 of Set 1 | shkotovo
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | arraial do cabo
# Processing Record 9 of Set 1 | limbang
# Processing Record 10 of Set 1 | waipawa
# Processing Record 11 of Set 1 | norman wells
# Processing Record 12 of Set 1 | bethel
# Processing Record 13 of Set 1 | port alfred
# Processing Record 14 of Set 1 | trairi
# Processing Record 15 of Set 1 | georgetown
# Processing Record 16 of Set 1 | hobart
# Processing Record 17 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 1 | palana
# Processing Record 20 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 1 | padang
# Processing Record 22 of Set 1 | lavrentiya
# Processing Record 23 of Set 1 | yuzhno-kurilsk
# Processing Record 24 of Set 1 | half moon bay
# Processing Record 25 of Set 1 | hasaki
# Processing Record 26 of Set 1 | chuy
# Processing Record 27 of Set 1 | portland
# Processing Record 28 of Set 1 | qaanaaq
# Processing Record 29 of Set 1 | hamilton
# Processing Record 30 of Set 1 | nikolskoye
# Processing Record 31 of Set 1 | yusva
# City not found. Skipping...
# Processing Record 32 of Set 1 | mataura
# Processing Record 33 of Set 1 | bengkulu
# Processing Record 34 of Set 1 | pevek
# Processing Record 35 of Set 1 | iqaluit
# Processing Record 36 of Set 1 | lebu
# Processing Record 37 of Set 1 | nouadhibou
# Processing Record 38 of Set 1 | rikitea
# Processing Record 39 of Set 1 | kununurra
# Processing Record 40 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 1 | saint-philippe
# Processing Record 42 of Set 1 | hoa binh
# Processing Record 43 of Set 1 | hilo
# Processing Record 44 of Set 1 | atuona
# Processing Record 45 of Set 1 | dingle
# Processing Record 46 of Set 1 | saldanha
# Processing Record 47 of Set 1 | busselton
# Processing Record 48 of Set 1 | westerland
# Processing Record 49 of Set 1 | mount isa
# Processing Record 50 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 2 of Set 2 | te anau
# Processing Record 3 of Set 2 | mahebourg
# Processing Record 4 of Set 2 | saravan
# Processing Record 5 of Set 2 | hithadhoo
# Processing Record 6 of Set 2 | kjollefjord
# Processing Record 7 of Set 2 | kodiak
# Processing Record 8 of Set 2 | cidreira
# Processing Record 9 of Set 2 | new norfolk
# Processing Record 10 of Set 2 | tautira
# Processing Record 11 of Set 2 | butaritari
# Processing Record 12 of Set 2 | carballo
# Processing Record 13 of Set 2 | albany
# Processing Record 14 of Set 2 | ribeira grande
# Processing Record 15 of Set 2 | kahului
# Processing Record 16 of Set 2 | victoria
# Processing Record 17 of Set 2 | tasiilaq
# Processing Record 18 of Set 2 | tiksi
# Processing Record 19 of Set 2 | port lincoln
# Processing Record 20 of Set 2 | mar del plata
# Processing Record 21 of Set 2 | larkana
# Processing Record 22 of Set 2 | saint anthony
# Processing Record 23 of Set 2 | saskylakh
# Processing Record 24 of Set 2 | khatanga
# Processing Record 25 of Set 2 | miyako
# Processing Record 26 of Set 2 | nome
# Processing Record 27 of Set 2 | sataua
# City not found. Skipping...
# Processing Record 28 of Set 2 | bonavista
# Processing Record 29 of Set 2 | poum
# Processing Record 30 of Set 2 | bluff
# Processing Record 31 of Set 2 | kurilsk
# Processing Record 32 of Set 2 | narsaq
# Processing Record 33 of Set 2 | el tocuyo
# Processing Record 34 of Set 2 | clyde river
# Processing Record 35 of Set 2 | the valley
# Processing Record 36 of Set 2 | souillac
# Processing Record 37 of Set 2 | sambava
# Processing Record 38 of Set 2 | rolla
# Processing Record 39 of Set 2 | quesnel
# Processing Record 40 of Set 2 | roebourne
# Processing Record 41 of Set 2 | kankaanpaa
# Processing Record 42 of Set 2 | cape town
# Processing Record 43 of Set 2 | guerrero negro
# Processing Record 44 of Set 2 | puerto baquerizo moreno
# Processing Record 45 of Set 2 | kamariotissa
# Processing Record 46 of Set 2 | muros
# Processing Record 47 of Set 2 | vostok
# Processing Record 48 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 49 of Set 2 | san vicente
# Processing Record 50 of Set 2 | preobrazheniye
# Processing Record 1 of Set 3 | luderitz
# Processing Record 2 of Set 3 | kapaa
# Processing Record 3 of Set 3 | syamzha
# Processing Record 4 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 3 | vaini
# Processing Record 6 of Set 3 | paita
# Processing Record 7 of Set 3 | thompson
# Processing Record 8 of Set 3 | kabinda
# Processing Record 9 of Set 3 | labytnangi
# Processing Record 10 of Set 3 | port keats
# Processing Record 11 of Set 3 | vila velha
# Processing Record 12 of Set 3 | resistencia
# Processing Record 13 of Set 3 | yinchuan
# Processing Record 14 of Set 3 | berlevag
# Processing Record 15 of Set 3 | alghero
# Processing Record 16 of Set 3 | bundaberg
# Processing Record 17 of Set 3 | castro
# Processing Record 18 of Set 3 | jamestown
# Processing Record 19 of Set 3 | sabang
# Processing Record 20 of Set 3 | dudinka
# Processing Record 21 of Set 3 | fortuna
# Processing Record 22 of Set 3 | port elizabeth
# Processing Record 23 of Set 3 | charlestown
# Processing Record 24 of Set 3 | sinjai
# Processing Record 25 of Set 3 | upernavik
# Processing Record 26 of Set 3 | talnakh
# Processing Record 27 of Set 3 | umm lajj
# Processing Record 28 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record 29 of Set 3 | pemba
# Processing Record 30 of Set 3 | cherskiy
# Processing Record 31 of Set 3 | sicamous
# Processing Record 32 of Set 3 | eunice
# Processing Record 33 of Set 3 | lodja
# Processing Record 34 of Set 3 | leningradskiy
# Processing Record 35 of Set 3 | hirado
# Processing Record 36 of Set 3 | oyo
# Processing Record 37 of Set 3 | vetlanda
# Processing Record 38 of Set 3 | dabat
# Processing Record 39 of Set 3 | plettenberg bay
# Processing Record 40 of Set 3 | karoi
# Processing Record 41 of Set 3 | port hardy
# Processing Record 42 of Set 3 | longyearbyen
# Processing Record 43 of Set 3 | iquique
# Processing Record 44 of Set 3 | lucea
# Processing Record 45 of Set 3 | tateyama
# Processing Record 46 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 3 | chokurdakh
# Processing Record 48 of Set 3 | gravelbourg
# Processing Record 49 of Set 3 | camacha
# Processing Record 50 of Set 3 | henties bay
# Processing Record 1 of Set 4 | qaqortoq
# Processing Record 2 of Set 4 | avarua
# Processing Record 3 of Set 4 | batagay-alyta
# Processing Record 4 of Set 4 | dikson
# Processing Record 5 of Set 4 | sitio novo do tocantins
# Processing Record 6 of Set 4 | wenling
# Processing Record 7 of Set 4 | tuktoyaktuk
# Processing Record 8 of Set 4 | san cristobal
# Processing Record 9 of Set 4 | dobson
# Processing Record 10 of Set 4 | niono
# Processing Record 11 of Set 4 | isangel
# Processing Record 12 of Set 4 | barrow
# Processing Record 13 of Set 4 | sosnovo-ozerskoye
# Processing Record 14 of Set 4 | kloulklubed
# Processing Record 15 of Set 4 | gravdal
# Processing Record 16 of Set 4 | lompoc
# Processing Record 17 of Set 4 | torbay
# Processing Record 18 of Set 4 | sao miguel do araguaia
# Processing Record 19 of Set 4 | shubarshi
# Processing Record 20 of Set 4 | puerto ayora
# Processing Record 21 of Set 4 | lorengau
# Processing Record 22 of Set 4 | coahuayana
# Processing Record 23 of Set 4 | yulara
# Processing Record 24 of Set 4 | san jeronimo
# Processing Record 25 of Set 4 | igarka
# Processing Record 26 of Set 4 | college
# Processing Record 27 of Set 4 | ancud
# Processing Record 28 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 29 of Set 4 | maryville
# Processing Record 30 of Set 4 | cowra
# Processing Record 31 of Set 4 | carutapera
# Processing Record 32 of Set 4 | general roca
# Processing Record 33 of Set 4 | sinnamary
# Processing Record 34 of Set 4 | kulhudhuffushi
# Processing Record 35 of Set 4 | belmonte
# Processing Record 36 of Set 4 | cabo san lucas
# Processing Record 37 of Set 4 | bayan
# Processing Record 38 of Set 4 | tabuk
# Processing Record 39 of Set 4 | srednekolymsk
# Processing Record 40 of Set 4 | dongsheng
# Processing Record 41 of Set 4 | rutul
# Processing Record 42 of Set 4 | provideniya
# Processing Record 43 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 4 | geraldton
# Processing Record 45 of Set 4 | east london
# Processing Record 46 of Set 4 | cauquenes
# Processing Record 47 of Set 4 | yurginskoye
# Processing Record 48 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 49 of Set 4 | hermanus
# Processing Record 50 of Set 4 | changping
# Processing Record 1 of Set 5 | lokosovo
# Processing Record 2 of Set 5 | los llanos de aridane
# Processing Record 3 of Set 5 | burica
# City not found. Skipping...
# Processing Record 4 of Set 5 | tomatlan
# Processing Record 5 of Set 5 | esperance
# Processing Record 6 of Set 5 | ponta do sol
# Processing Record 7 of Set 5 | izumo
# Processing Record 8 of Set 5 | stornoway
# Processing Record 9 of Set 5 | noumea
# Processing Record 10 of Set 5 | sao filipe
# Processing Record 11 of Set 5 | paamiut
# Processing Record 12 of Set 5 | yerbogachen
# Processing Record 13 of Set 5 | alto piquiri
# Processing Record 14 of Set 5 | marang
# Processing Record 15 of Set 5 | pisco
# Processing Record 16 of Set 5 | dafeng
# Processing Record 17 of Set 5 | along
# Processing Record 18 of Set 5 | emba
# Processing Record 19 of Set 5 | nouakchott
# Processing Record 20 of Set 5 | kruisfontein
# Processing Record 21 of Set 5 | tura
# Processing Record 22 of Set 5 | khudumelapye
# Processing Record 23 of Set 5 | barcelos
# Processing Record 24 of Set 5 | lixourion
# Processing Record 25 of Set 5 | bilaspur
# Processing Record 26 of Set 5 | vao
# Processing Record 27 of Set 5 | salalah
# Processing Record 28 of Set 5 | phan thiet
# Processing Record 29 of Set 5 | ilulissat
# Processing Record 30 of Set 5 | mount gambier
# Processing Record 31 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 5 | banos
# Processing Record 33 of Set 5 | thinadhoo
# Processing Record 34 of Set 5 | cacule
# Processing Record 35 of Set 5 | saint-pierre
# Processing Record 36 of Set 5 | jingdezhen
# Processing Record 37 of Set 5 | labuan
# Processing Record 38 of Set 5 | lakeway
# Processing Record 39 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 5 | hobyo
# Processing Record 41 of Set 5 | ostrovskoye
# Processing Record 42 of Set 5 | ivybridge
# Processing Record 43 of Set 5 | nacala
# Processing Record 44 of Set 5 | axim
# Processing Record 45 of Set 5 | anori
# Processing Record 46 of Set 5 | zlynka
# Processing Record 47 of Set 5 | chapais
# Processing Record 48 of Set 5 | conceicao do araguaia
# Processing Record 49 of Set 5 | hanzhong
# Processing Record 50 of Set 5 | chissamba
# Processing Record 1 of Set 6 | maturin
# Processing Record 2 of Set 6 | kuryk
# Processing Record 3 of Set 6 | greenwood
# Processing Record 4 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 6 | forestville
# Processing Record 6 of Set 6 | trincomalee
# Processing Record 7 of Set 6 | alta floresta
# Processing Record 8 of Set 6 | van
# Processing Record 9 of Set 6 | belaya gora
# Processing Record 10 of Set 6 | fort saint john
# City not found. Skipping...
# Processing Record 11 of Set 6 | pochutla
# Processing Record 12 of Set 6 | bredasdorp
# Processing Record 13 of Set 6 | torata
# Processing Record 14 of Set 6 | port augusta
# Processing Record 15 of Set 6 | lazaro cardenas
# Processing Record 16 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 6 | zhigansk
# Processing Record 18 of Set 6 | haines junction
# Processing Record 19 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 20 of Set 6 | stillwater
# Processing Record 21 of Set 6 | fairbanks
# Processing Record 22 of Set 6 | black river
# Processing Record 23 of Set 6 | maraba
# Processing Record 24 of Set 6 | karagaylinskiy
# Processing Record 25 of Set 6 | kaitangata
# Processing Record 26 of Set 6 | lagoa
# Processing Record 27 of Set 6 | brae
# Processing Record 28 of Set 6 | vakhrushevo
# Processing Record 29 of Set 6 | dunedin
# Processing Record 30 of Set 6 | dolores
# Processing Record 31 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 6 | majalgaon
# Processing Record 33 of Set 6 | xining
# Processing Record 34 of Set 6 | yerkoy
# Processing Record 35 of Set 6 | nam tha
# City not found. Skipping...
# Processing Record 36 of Set 6 | san patricio
# Processing Record 37 of Set 6 | coffs harbour
# Processing Record 38 of Set 6 | ulladulla
# Processing Record 39 of Set 6 | bereda
# Processing Record 40 of Set 6 | necochea
# Processing Record 41 of Set 6 | kapoeta
# Processing Record 42 of Set 6 | bela
# Processing Record 43 of Set 6 | sola
# Processing Record 44 of Set 6 | tezu
# Processing Record 45 of Set 6 | timizart
# Processing Record 46 of Set 6 | mackay
# Processing Record 47 of Set 6 | urdzhar
# City not found. Skipping...
# Processing Record 48 of Set 6 | forbes
# Processing Record 49 of Set 6 | fort frances
# Processing Record 50 of Set 6 | aklavik
# Processing Record 1 of Set 7 | hot springs
# Processing Record 2 of Set 7 | leh
# Processing Record 3 of Set 7 | manzil jamil
# City not found. Skipping...
# Processing Record 4 of Set 7 | talcahuano
# Processing Record 5 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 6 of Set 7 | vanimo
# Processing Record 7 of Set 7 | eyl
# Processing Record 8 of Set 7 | nelson bay
# Processing Record 9 of Set 7 | fare
# Processing Record 10 of Set 7 | bokspits
# City not found. Skipping...
# Processing Record 11 of Set 7 | alofi
# Processing Record 12 of Set 7 | faanui
# Processing Record 13 of Set 7 | amroha
# Processing Record 14 of Set 7 | san benito
# Processing Record 15 of Set 7 | wanning
# Processing Record 16 of Set 7 | bilara
# Processing Record 17 of Set 7 | gold coast
# Processing Record 18 of Set 7 | klaksvik
# Processing Record 19 of Set 7 | sciacca
# Processing Record 20 of Set 7 | kadhan
# Processing Record 21 of Set 7 | hlubocky
# Processing Record 22 of Set 7 | uige
# Processing Record 23 of Set 7 | kieta
# Processing Record 24 of Set 7 | bowen
# Processing Record 25 of Set 7 | yellowknife
# Processing Record 26 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 7 | sur
# Processing Record 28 of Set 7 | marrakesh
# Processing Record 29 of Set 7 | premia de mar
# Processing Record 30 of Set 7 | vardo
# Processing Record 31 of Set 7 | vangaindrano
# Processing Record 32 of Set 7 | kenai
# Processing Record 33 of Set 7 | stolin
# Processing Record 34 of Set 7 | avallon
# Processing Record 35 of Set 7 | eskasem
# City not found. Skipping...
# Processing Record 36 of Set 7 | mayo
# Processing Record 37 of Set 7 | shetpe
# Processing Record 38 of Set 7 | peniche
# Processing Record 39 of Set 7 | sierre
# Processing Record 40 of Set 7 | kibondo
# Processing Record 41 of Set 7 | guadalupe y calvo
# Processing Record 42 of Set 7 | grasse
# Processing Record 43 of Set 7 | namie
# Processing Record 44 of Set 7 | ixtapa
# Processing Record 45 of Set 7 | port-gentil
# Processing Record 46 of Set 7 | kavaratti
# Processing Record 47 of Set 7 | port moresby
# Processing Record 48 of Set 7 | palmer
# Processing Record 49 of Set 7 | qidong
# Processing Record 50 of Set 7 | yumen
# Processing Record 1 of Set 8 | sapulpa
# Processing Record 2 of Set 8 | russell
# Processing Record 3 of Set 8 | olutanga
# Processing Record 4 of Set 8 | edea
# Processing Record 5 of Set 8 | norfolk
# Processing Record 6 of Set 8 | adrar
# Processing Record 7 of Set 8 | pringsewu
# Processing Record 8 of Set 8 | ust-nera
# Processing Record 9 of Set 8 | marquette
# Processing Record 10 of Set 8 | volosovo
# Processing Record 11 of Set 8 | nadym
# Processing Record 12 of Set 8 | caxias
# Processing Record 13 of Set 8 | tecoanapa
# Processing Record 14 of Set 8 | katherine
# Processing Record 15 of Set 8 | saint-augustin
# Processing Record 16 of Set 8 | nanortalik
# Processing Record 17 of Set 8 | vila franca do campo
# Processing Record 18 of Set 8 | nchelenge
# Processing Record 19 of Set 8 | xai-xai
# Processing Record 20 of Set 8 | nurota
# Processing Record 21 of Set 8 | samarai
# Processing Record 22 of Set 8 | airai
# Processing Record 23 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 8 | okhotsk
# Processing Record 25 of Set 8 | klyuchi
# Processing Record 26 of Set 8 | mgachi
# Processing Record 27 of Set 8 | chimbote
# Processing Record 28 of Set 8 | saint george
# Processing Record 29 of Set 8 | beringovskiy
# Processing Record 30 of Set 8 | coihaique
# Processing Record 31 of Set 8 | tanete
# Processing Record 32 of Set 8 | husavik
# Processing Record 33 of Set 8 | isiro
# Processing Record 34 of Set 8 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 35 of Set 8 | ketchikan
# Processing Record 36 of Set 8 | richards bay
# Processing Record 37 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 38 of Set 8 | goderich
# Processing Record 39 of Set 8 | port hedland
# Processing Record 40 of Set 8 | sarny
# Processing Record 41 of Set 8 | bentiu
# Processing Record 42 of Set 8 | waddan
# Processing Record 43 of Set 8 | afmadu
# City not found. Skipping...
# Processing Record 44 of Set 8 | moundou
# Processing Record 45 of Set 8 | garden city
# Processing Record 46 of Set 8 | ust-shonosha
# Processing Record 47 of Set 8 | puerto escondido
# Processing Record 48 of Set 8 | aykhal
# Processing Record 49 of Set 8 | finote selam
# Processing Record 50 of Set 8 | sitka
# Processing Record 1 of Set 9 | penzance
# Processing Record 2 of Set 9 | quartz hill
# Processing Record 3 of Set 9 | hirara
# Processing Record 4 of Set 9 | campbell river
# Processing Record 5 of Set 9 | ardakan
# Processing Record 6 of Set 9 | cirpan
# City not found. Skipping...
# Processing Record 7 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 8 of Set 9 | vila
# Processing Record 9 of Set 9 | kavieng
# Processing Record 10 of Set 9 | sorland
# Processing Record 11 of Set 9 | dali
# Processing Record 12 of Set 9 | banda aceh
# Processing Record 13 of Set 9 | moro
# Processing Record 14 of Set 9 | salvador
# Processing Record 15 of Set 9 | sept-iles
# Processing Record 16 of Set 9 | pipar
# Processing Record 17 of Set 9 | batemans bay
# Processing Record 18 of Set 9 | hun
# Processing Record 19 of Set 9 | karwar
# Processing Record 20 of Set 9 | basco
# Processing Record 21 of Set 9 | mana
# Processing Record 22 of Set 9 | hambantota
# Processing Record 23 of Set 9 | puerto colombia
# Processing Record 24 of Set 9 | huancabamba
# Processing Record 25 of Set 9 | agrado
# Processing Record 26 of Set 9 | hokitika
# Processing Record 27 of Set 9 | athabasca
# Processing Record 28 of Set 9 | denpasar
# Processing Record 29 of Set 9 | senneterre
# Processing Record 30 of Set 9 | bansang
# Processing Record 31 of Set 9 | serenje
# Processing Record 32 of Set 9 | ji-parana
# City not found. Skipping...
# Processing Record 33 of Set 9 | santa ana
# Processing Record 34 of Set 9 | takaka
# Processing Record 35 of Set 9 | vaasa
# Processing Record 36 of Set 9 | port blair
# Processing Record 37 of Set 9 | tuatapere
# Processing Record 38 of Set 9 | coquimbo
# Processing Record 39 of Set 9 | ust-kuyga
# Processing Record 40 of Set 9 | aleksandrovskiy zavod
# Processing Record 41 of Set 9 | serdobsk
# Processing Record 42 of Set 9 | meulaboh
# Processing Record 43 of Set 9 | corinth
# Processing Record 44 of Set 9 | marienburg
# Processing Record 45 of Set 9 | grand-lahou
# Processing Record 46 of Set 9 | venado tuerto
# Processing Record 47 of Set 9 | luanda
# Processing Record 48 of Set 9 | tabou
# Processing Record 49 of Set 9 | charters towers
# Processing Record 50 of Set 9 | banikoara
# Processing Record 1 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 10 | bom jesus da lapa
# Processing Record 3 of Set 10 | abalak
# Processing Record 4 of Set 10 | wuwei
# Processing Record 5 of Set 10 | achkhoy-martan
# Processing Record 6 of Set 10 | nicoya
# Processing Record 7 of Set 10 | praya
# Processing Record 8 of Set 10 | abbeville
# Processing Record 9 of Set 10 | desnogorsk
# Processing Record 10 of Set 10 | mutoko
# Processing Record 11 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 12 of Set 10 | cruden bay
# City not found. Skipping...
# Processing Record 13 of Set 10 | listica
# City not found. Skipping...
# Processing Record 14 of Set 10 | gurgan
# City not found. Skipping...
# Processing Record 15 of Set 10 | asyut
# Processing Record 16 of Set 10 | melnikovo
# Processing Record 17 of Set 10 | mount pleasant
# Processing Record 18 of Set 10 | yuanping
# Processing Record 19 of Set 10 | candolim
# Processing Record 20 of Set 10 | port shepstone
# Processing Record 21 of Set 10 | peno
# Processing Record 22 of Set 10 | matay
# Processing Record 23 of Set 10 | nagapattinam
# Processing Record 24 of Set 10 | saint-joseph
# Processing Record 25 of Set 10 | taoudenni
# Processing Record 26 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 27 of Set 10 | didao
# Processing Record 28 of Set 10 | luangwa
# Processing Record 29 of Set 10 | kankan
# Processing Record 30 of Set 10 | dong hoi
# Processing Record 31 of Set 10 | alamogordo
# Processing Record 32 of Set 10 | mchinji
# Processing Record 33 of Set 10 | road town
# Processing Record 34 of Set 10 | northam
# Processing Record 35 of Set 10 | soe
# Processing Record 36 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 37 of Set 10 | seymchan
# Processing Record 38 of Set 10 | thunder bay
# Processing Record 39 of Set 10 | constitucion
# Processing Record 40 of Set 10 | diego de almagro
# Processing Record 41 of Set 10 | rock hill
# Processing Record 42 of Set 10 | roma
# Processing Record 43 of Set 10 | assiniboia
# Processing Record 44 of Set 10 | moberly
# Processing Record 45 of Set 10 | sanford
# Processing Record 46 of Set 10 | newport
# Processing Record 47 of Set 10 | hargeysa
# Processing Record 48 of Set 10 | asayita
# City not found. Skipping...
# Processing Record 49 of Set 10 | vieques
# Processing Record 50 of Set 10 | maxixe
# Processing Record 1 of Set 11 | abu samrah
# Processing Record 2 of Set 11 | sasvad
# Processing Record 3 of Set 11 | malindi
# Processing Record 4 of Set 11 | severnyy-kospashskiy
# Processing Record 5 of Set 11 | merauke
# Processing Record 6 of Set 11 | bow island
# Processing Record 7 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 8 of Set 11 | sistranda
# Processing Record 9 of Set 11 | itoman
# Processing Record 10 of Set 11 | kuusamo
# Processing Record 11 of Set 11 | tubig indangan
# City not found. Skipping...
# Processing Record 12 of Set 11 | tsiroanomandidy
# Processing Record 13 of Set 11 | puerto palomas
# Processing Record 14 of Set 11 | minsk
# Processing Record 15 of Set 11 | muzhi
# Processing Record 16 of Set 11 | hay river
# Processing Record 17 of Set 11 | lebanon
# Processing Record 18 of Set 11 | san policarpo
# Processing Record 19 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 20 of Set 11 | gboko
# Processing Record 21 of Set 11 | westport
# Processing Record 22 of Set 11 | antalaha
# Processing Record 23 of Set 11 | destin
# Processing Record 24 of Set 11 | lurgan
# Processing Record 25 of Set 11 | quepos
# Processing Record 26 of Set 11 | steamboat springs
# Processing Record 27 of Set 11 | liepaja
# Processing Record 28 of Set 11 | rongcheng
# Processing Record 29 of Set 11 | khasan
# Processing Record 30 of Set 11 | asino
# Processing Record 31 of Set 11 | college place
# Processing Record 32 of Set 11 | hadishahr
# Processing Record 33 of Set 11 | karamay
# City not found. Skipping...
# Processing Record 34 of Set 11 | alyangula
# Processing Record 35 of Set 11 | asau
# Processing Record 36 of Set 11 | kropotkin
# Processing Record 37 of Set 11 | temir
# Processing Record 38 of Set 11 | clinton
# Processing Record 39 of Set 11 | kaili
# Processing Record 40 of Set 11 | hovd
# Processing Record 41 of Set 11 | riyadh
# Processing Record 42 of Set 11 | matsanga
# City not found. Skipping...
# Processing Record 43 of Set 11 | ondorhaan
# City not found. Skipping...
# Processing Record 44 of Set 11 | gat
# Processing Record 45 of Set 11 | takaungu
# Processing Record 46 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 11 | callaway
# Processing Record 48 of Set 11 | sao borja
# Processing Record 49 of Set 11 | linda
# Processing Record 50 of Set 11 | taltal
# Processing Record 1 of Set 12 | cururupu
# Processing Record 2 of Set 12 | inuvik
# Processing Record 3 of Set 12 | ust-tsilma
# Processing Record 4 of Set 12 | sungaipenuh
# Processing Record 5 of Set 12 | yar-sale
# Processing Record 6 of Set 12 | indianola
# Processing Record 7 of Set 12 | filadelfia
# Processing Record 8 of Set 12 | hami
# Processing Record 9 of Set 12 | khash
# Processing Record 10 of Set 12 | verkh-usugli
# Processing Record 11 of Set 12 | mehamn
# Processing Record 12 of Set 12 | bogo
# Processing Record 13 of Set 12 | sandakan
# Processing Record 14 of Set 12 | bubaque
# Processing Record 15 of Set 12 | olafsvik
# Processing Record 16 of Set 12 | rorvik
# Processing Record 17 of Set 12 | clausthal-zellerfeld
# Processing Record 18 of Set 12 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 12 | tajimi
# Processing Record 20 of Set 12 | pacific grove
# Processing Record 21 of Set 12 | ostrovnoy
# Processing Record 22 of Set 12 | karasjok
# Processing Record 23 of Set 12 | shar
# Processing Record 24 of Set 12 | craig
# Processing Record 25 of Set 12 | bata
# Processing Record 26 of Set 12 | buala
# Processing Record 27 of Set 12 | alice springs
# Processing Record 28 of Set 12 | acarau
# Processing Record 29 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 30 of Set 12 | baykit
# Processing Record 31 of Set 12 | barstow
# Processing Record 32 of Set 12 | olavarria
# Processing Record 33 of Set 12 | lianran
# Processing Record 34 of Set 12 | artyom
# Processing Record 35 of Set 12 | gusau
# Processing Record 36 of Set 12 | kondinskoye
# Processing Record 37 of Set 12 | panguna
# Processing Record 38 of Set 12 | acapulco
# Processing Record 39 of Set 12 | mogadishu
# Processing Record 40 of Set 12 | shuangcheng
# Processing Record 41 of Set 12 | harper
# Processing Record 42 of Set 12 | paragominas
# Processing Record 43 of Set 12 | la baule-escoublac
# Processing Record 44 of Set 12 | turka
# Processing Record 45 of Set 12 | karakendzha
# City not found. Skipping...
# Processing Record 46 of Set 12 | ola
# Processing Record 47 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 48 of Set 12 | srandakan
# Processing Record 49 of Set 12 | cam ranh
# Processing Record 50 of Set 12 | christchurch
# Processing Record 1 of Set 13 | florian
# Processing Record 2 of Set 13 | ambilobe
# Processing Record 3 of Set 13 | anadyr
# Processing Record 4 of Set 13 | nuuk
# Processing Record 5 of Set 13 | kiruna
# Processing Record 6 of Set 13 | robertsport
# Processing Record 7 of Set 13 | taitung
# Processing Record 8 of Set 13 | menongue
# Processing Record 9 of Set 13 | itaituba
# Processing Record 10 of Set 13 | surt
# Processing Record 11 of Set 13 | san luis
# Processing Record 12 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 13 of Set 13 | opuwo
# Processing Record 14 of Set 13 | saint-georges
# Processing Record 15 of Set 13 | malakal
# Processing Record 16 of Set 13 | harnosand
# Processing Record 17 of Set 13 | grindavik
# Processing Record 18 of Set 13 | locri
# Processing Record 19 of Set 13 | lata
# Processing Record 20 of Set 13 | tome
# Processing Record 21 of Set 13 | turukhansk
# Processing Record 22 of Set 13 | wewak
# Processing Record 23 of Set 13 | siena
# Processing Record 24 of Set 13 | boa vista
# Processing Record 25 of Set 13 | severnoye
# Processing Record 26 of Set 13 | kralendijk
# Processing Record 27 of Set 13 | ngunguru
# Processing Record 28 of Set 13 | ducos
# Processing Record 29 of Set 13 | marsa matruh
# Processing Record 30 of Set 13 | imeni poliny osipenko
# Processing Record 31 of Set 13 | ballina
# Processing Record 32 of Set 13 | bandarbeyla
# Processing Record 33 of Set 13 | rio grande
# Processing Record 34 of Set 13 | maua
# Processing Record 35 of Set 13 | kutum
# Processing Record 36 of Set 13 | kenora
# Processing Record 37 of Set 13 | sid
# Processing Record 38 of Set 13 | lere
# Processing Record 39 of Set 13 | rach gia
# Processing Record 40 of Set 13 | putina
# Processing Record 41 of Set 13 | severo-kurilsk
# Processing Record 42 of Set 13 | makinsk
# Processing Record 43 of Set 13 | coolum beach
# Processing Record 44 of Set 13 | el bagre
# Processing Record 45 of Set 13 | pedernales
# Processing Record 46 of Set 13 | sungairaya
# Processing Record 47 of Set 13 | avera
# Processing Record 48 of Set 13 | altamira
# Processing Record 49 of Set 13 | otane
# Processing Record 50 of Set 13 | arman
# Processing Record 1 of Set 14 | borovoy
# Processing Record 2 of Set 14 | gamba
# Processing Record 3 of Set 14 | tocopilla
# Processing Record 4 of Set 14 | hohhot
# Processing Record 5 of Set 14 | maunabo
# Processing Record 6 of Set 14 | san fernando
# Processing Record 7 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 14 | padilla
# Processing Record 9 of Set 14 | plastun
# Processing Record 10 of Set 14 | bulgan
# Processing Record 11 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 12 of Set 14 | tucuman
# Processing Record 13 of Set 14 | maple creek
# Processing Record 14 of Set 14 | chicama
# Processing Record 15 of Set 14 | natal
# Processing Record 16 of Set 14 | zachagansk
# City not found. Skipping...
# Processing Record 17 of Set 14 | porto novo
# Processing Record 18 of Set 14 | beisfjord
# Processing Record 19 of Set 14 | rawatsar
# Processing Record 20 of Set 14 | abu dhabi
# Processing Record 21 of Set 14 | marataizes
# Processing Record 22 of Set 14 | plouzane
# Processing Record 23 of Set 14 | valparaiso
# Processing Record 24 of Set 14 | itarema
# Processing Record 25 of Set 14 | cap malheureux
# Processing Record 26 of Set 14 | havelock
# Processing Record 27 of Set 14 | ahipara
# Processing Record 28 of Set 14 | bhadra
# Processing Record 29 of Set 14 | barranca
# Processing Record 30 of Set 14 | falam
# Processing Record 31 of Set 14 | zyryanka
# Processing Record 32 of Set 14 | oda
# Processing Record 33 of Set 14 | morondava
# Processing Record 34 of Set 14 | naryan-mar
# Processing Record 35 of Set 14 | epinal
# Processing Record 36 of Set 14 | wa
# City not found. Skipping...
# Processing Record 37 of Set 14 | noyabrsk
# Processing Record 38 of Set 14 | miri
# Processing Record 39 of Set 14 | sydney
# Processing Record 40 of Set 14 | manoel urbano
# Processing Record 41 of Set 14 | imbituba
# Processing Record 42 of Set 14 | hofn
# Processing Record 43 of Set 14 | champasak
# Processing Record 44 of Set 14 | reconquista
# Processing Record 45 of Set 14 | ahuimanu
# Processing Record 46 of Set 14 | kalispell
# Processing Record 47 of Set 14 | vastseliina
# Processing Record 48 of Set 14 | el tarra
# Processing Record 49 of Set 14 | kizukuri
# Processing Record 50 of Set 14 | valle hermoso
# Processing Record 1 of Set 15 | kaeo
# Processing Record 2 of Set 15 | waingapu
# Processing Record 3 of Set 15 | nhlangano
# Processing Record 4 of Set 15 | kamaishi
# Processing Record 5 of Set 15 | caravelas
# Processing Record 6 of Set 15 | rawah
# Processing Record 7 of Set 15 | birjand
# Processing Record 8 of Set 15 | tuni
# Processing Record 9 of Set 15 | kadykchan
# City not found. Skipping...
# Processing Record 10 of Set 15 | kontagora
# Processing Record 11 of Set 15 | ambanja
# Processing Record 12 of Set 15 | buraydah
# Processing Record 13 of Set 15 | obo
# Processing Record 14 of Set 15 | pierre
# Processing Record 15 of Set 15 | horn lake
# Processing Record 16 of Set 15 | oranjemund
# Processing Record 17 of Set 15 | kuala lumpur
# Processing Record 18 of Set 15 | datong
# Processing Record 19 of Set 15 | sandnessjoen
# Processing Record 20 of Set 15 | susehri
# Processing Record 21 of Set 15 | namatanai
# Processing Record 22 of Set 15 | gornyak
# Processing Record 23 of Set 15 | hunza
# City not found. Skipping...
# Processing Record 24 of Set 15 | codrington
# Processing Record 25 of Set 15 | guarapari
# Processing Record 26 of Set 15 | carmen
# Processing Record 27 of Set 15 | babanusah
# City not found. Skipping...
# Processing Record 28 of Set 15 | domoni
# Processing Record 29 of Set 15 | nova olimpia
# Processing Record 30 of Set 15 | prilep
# Processing Record 31 of Set 15 | enghien
# Processing Record 32 of Set 15 | minas
# Processing Record 33 of Set 15 | dolbeau
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 668

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Anchorage  61.22 -149.90     63.00        48           1        6.93
# 1        Carnarvon -24.87  113.63     55.40        62           0       10.29
# 2         Maragogi  -9.01  -35.22     75.04        82          24       10.85
# 3     Punta Arenas -53.15  -70.92     39.20        86          75       28.86
# 4        Bathsheba  13.22  -59.52     80.60        83          75       18.34
# 5         Shkotovo  43.33  132.36     68.00       100          75        4.47
# 6          Ushuaia -54.80  -68.30     33.80        93          90       23.04
# 7  Arraial Do Cabo -22.97  -42.03     73.40        83           0       17.22
# 8          Limbang   4.75  115.00     78.80        88          75        1.12
# 9          Waipawa -41.41  175.52     57.99        67          17       21.92
#
#   Country          Current Description
# 0      US                    clear sky
# 1      AU                    clear sky
# 2      BR                   few clouds
# 3      CL                broken clouds
# 4      BB                  shower rain
# 5      RU  light intensity shower rain
# 6      AR                   light snow
# 7      BR                    clear sky
# 8      MY                broken clouds
# 9      NZ                   few clouds

# %%
# reorder columns
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df= city_data_df[new_column_order]
city_data_df
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0       Anchorage      US  61.22 -149.90     63.00        48           1
# 1       Carnarvon      AU -24.87  113.63     55.40        62           0
# 2        Maragogi      BR  -9.01  -35.22     75.04        82          24
# 3    Punta Arenas      CL -53.15  -70.92     39.20        86          75
# 4       Bathsheba      BB  13.22  -59.52     80.60        83          75
# ..            ...     ...    ...     ...       ...       ...         ...
# 663        Domoni      KM -12.26   44.53     73.29        74           0
# 664  Nova Olimpia      BR -14.80  -57.29     91.51        11           0
# 665        Prilep      MK  41.35   21.55     68.00        72           0
# 666       Enghien      BE  50.69    4.03     55.99        93           8
# 667         Minas      UY -34.38  -55.24     53.60        87          75
#
#      Wind Speed Current Description
# 0          6.93           clear sky
# 1         10.29           clear sky
# 2         10.85          few clouds
# 3         28.86       broken clouds
# 4         18.34         shower rain
# ..          ...                 ...
# 663        3.42           clear sky
# 664        5.77           clear sky
# 665        1.95           clear sky
# 666        4.70           clear sky
# 667       13.87          light rain
#
# [668 rows x 9 columns]

# %%
#added a new folder called Weather_Database
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
